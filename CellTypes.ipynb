# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(-0.03022698366242723), np.float64(0.9835413548997247))

# %% [markdown]
# # Step 3: Cell types
#
# Code cells run Python and show the output:
#
# ```python
# import numpy as np
# data = np.random.randn(1000)
# data.mean(), data.std()
